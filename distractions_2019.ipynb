# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('car_distractions_2019.csv')

# %%
df
# Out:
#                                                          Distracted drivers in fatal crashes during 2019, by distraction type
# Distraction Type                                  Number                                                  %
# Generally distracted/Day dreaming                 1,872                                                  62
# Cellphone use                                     390                                                    13
# Rubbernecking                                     218                                                     7
# Other distraction, not specified                  203                                                     7
# Talking with or looking at other people in car    134                                                     4
# Using or reaching for device brought into vehicle 111                                                     4
# ...

# %%
Distractions=['Generally distracted/ Day dreaming','Cellphone use','Rubbernecking','Other distraction, not specified','Talking with or looking at other people in car','Using or reaching for device brought into vehicle','Eating or drinking','Adjusting audio or climate controls','Using other device/controls integral to vehicle','Moving object in vehicle, such as pet or insect','Smoking related', 'All distracted drivers']
Accidents=[1872,390,218,203,134,111,44,22,18,12,6,3008]
plt.bar (Distractions, Accidents, color ="r")
plt.xlabel ("Distractions")
plt.ylabel("Accidents")
plt.title("Fatal Crashes 2019")
plt.xticks(rotation=50, ha='right')
plt.rcParams['figure.figsize'] = [10, 10]
plt.show()
